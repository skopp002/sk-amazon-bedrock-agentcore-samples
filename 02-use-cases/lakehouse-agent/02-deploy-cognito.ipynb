# %% [markdown]
# # Deploy Cognito
#
# Set up user authentication with AWS Cognito.

# %% [markdown]
# ## Prerequisites
#
# - ✅ Run `01-deploy-athena.ipynb` first
#
# ## What This Notebook Does
#
# 1. Creates Cognito User Pool
# 2. Creates App Client with OAuth scopes
# 3. Creates test users
# 4. Saves configuration to SSM
#
# ## Next Notebook
#
# - **03-deploy-mcp-server.ipynb**

# %%
import sys
sys.path.insert(0, '.')  # Add current directory to path
from pathlib import Path
from aws_session_utils import get_aws_session

# Get validated AWS session with SSO support
session, region, account_id = get_aws_session()

# Initialize AWS clients
cognito_client = session.client('cognito-idp', region_name=region)
ssm_client = session.client('ssm', region_name=region)

print(f'✅ Setup complete - Region: {region}')
# Out:
# 🔍 Using default AWS credentials (no profile specified)
# ⚠️  No AWS region configured, using default: us-east-1
#    To set your region:
#    - Environment variable: export AWS_DEFAULT_REGION=your-region
#    - AWS CLI: aws configure set region your-region
#
# ✅ AWS Credentials Validated
#    Region: us-east-1
#    Account ID: XXXXXXXXXXXX
#    Profile: default
#    Auth method: AWS SSO
#
# ✅ Setup complete - Region: us-east-1

# %% [markdown]
# ## Step 1: Run Cognito Setup

# %%
import subprocess

result = subprocess.run(
    ['python', 'setup_cognito.py', '--region', region],
    cwd='cognito-setup',
    capture_output=True,
    text=True
)

print(result.stdout)
if result.returncode != 0:
    print('❌ Error:', result.stderr)
else:
    print('\n✅ Cognito setup complete!')
    print('\n📋 Configuration automatically saved to SSM Parameter Store')
# Out:
# 🔍 Using default AWS credentials (no profile specified)
# ⚠️  No AWS region configured, using default: us-east-1
#    To set your region:
#    - Environment variable: export AWS_DEFAULT_REGION=your-region
#    - AWS CLI: aws configure set region your-region
#
# ✅ AWS Credentials Validated
#    Region: us-east-1
#    Account ID: XXXXXXXXXXXX
#    Profile: default
#    Auth method: AWS SSO
#
# Initialized Cognito setup for region: us-east-1
# ℹ️  Found existing User Pool: us-east-1_3jSGececJ
# ✅ Using existing User Pool: us-east-1_3jSGececJ
#    ⚠️  Warning: If this pool was created with UsernameAttributes=['email'],
#       users will have UUID usernames. Delete the pool and recreate, or
#       run cleanup_test_users.py to delete old users.
# ℹ️  Resource Server already exists
# ℹ️  Found existing App Client: comfh80kmr0a3mlrusl6cmulu
# ℹ️  App Client exists: comfh80kmr0a3mlrusl6cmulu
#    Updating to support both client_credentials and user authentication...
# ✅ App Client updated to support user authentication and client_credentials
# ℹ️  Found existing domain: https://lakehouse-useast13.auth.us-east-1.amazoncognito.com
# ✅ Using existing domain: https://lakehouse-useast13.auth.us-east-1.amazoncognito.com
# ℹ️  Test user already exists: user001@example.com
# ℹ️  Test user already exists: user002@example.com
# ℹ️  Test user already exists: adjuster001@example.com
#
# 🤖 Creating M2M-only app client...
#    Using reference client: 54sj5fk27eqtbt5c7rghv1fjkq
#    ⚠️  Could not read reference client: An error occurred (ResourceNotFoundException) when calling the DescribeUserPoolClient operation: User pool client does not exist.
#    Using default M2M configuration
# ℹ️  Found existing App Client: 6dls2pick0ekciocqckh6s02ss
# ℹ️  M2M App Client exists: 6dls2pick0ekciocqckh6s02ss
#    Updating with reference configuration...
# ✅ M2M App Client updated (copied from reference)
#
# 💾 Storing configuration in SSM Parameter Store...
# ✅ Stored parameter (SecureString): /app/lakehouse-agent/cognito-app-client-secret
# ✅ Stored parameter (SecureString): /app/lakehouse-agent/cognito-m2m-client-secret
# ✅ Stored parameter: /app/lakehouse-agent/cognito-user-pool-id = us-east-1_3jSGececJ
# ✅ Stored parameter: /app/lakehouse-agent/cognito-user-pool-arn = arn:aws:cognito-idp:us-east-1:XXXXXXXXXXXX:userpool/us-east-1_3jSGececJ
# ✅ Stored parameter: /app/lakehouse-agent/cognito-app-client-id = comfh80kmr0a3mlrusl6cmulu
# ✅ Stored parameter: /app/lakehouse-agent/cognito-domain = https://lakehouse-useast13.auth.us-east-1.amazoncognito.com
# ✅ Stored parameter: /app/lakehouse-agent/cognito-resource-server-id = lakehouse-api
# ✅ Stored parameter: /app/lakehouse-agent/cognito-region = us-east-1
# ✅ Stored parameter: /app/lakehouse-agent/cognito-m2m-client-id = 6dls2pick0ekciocqckh6s02ss
#
# 📝 Configuration:
# {
#   "user_pool_id": "us-east-1_3jSGececJ",
#   "client_id": "comfh80kmr0a3mlrusl6cmulu",
#   "domain": "https://lakehouse-useast13.auth.us-east-1.amazoncognito.com",
#   "m2m_client_id": "6dls2pick0ekciocqckh6s02ss"
# }
#
# 🔐 User App Client Secret: 1isptb1qcbo1nt6s8851atdql5lk8sus68gootmg39p802hjjst1
#    (Also stored securely in SSM Parameter Store)
#
# 🤖 M2M App Client Secret: 15qmkmjmq5vl5jb8jganbmedaah3hruhj3b18gaco88evk8brcod
#    (Also stored securely in SSM Parameter Store)
#
# 💾 SSM Parameters Stored:
#    • /app/lakehouse-agent/cognito-user-pool-id
#    • /app/lakehouse-agent/cognito-user-pool-arn
#    • /app/lakehouse-agent/cognito-app-client-id (user auth + M2M)
#    • /app/lakehouse-agent/cognito-app-client-secret (SecureString)
#    • /app/lakehouse-agent/cognito-m2m-client-id (M2M only)
#    • /app/lakehouse-agent/cognito-m2m-client-secret (SecureString)
#    • /app/lakehouse-agent/cognito-domain
#    • /app/lakehouse-agent/cognito-resource-server-id
#    • /app/lakehouse-agent/cognito-region
#
# 👥 Test Users Created:
#    • user001@example.com (username: user001@example.com)
#    • user002@example.com (username: user002@example.com)
#    • adjuster001@example.com (username: adjuster001@example.com)
#    Default password: TempPass123!
#    Note: Users will be prompted to change password on first login
#
# 🔑 App Clients:
#    1. lakehouse-client (ID: comfh80kmr0a3mlrusl6cmulu)
#       - Supports: User authentication (SRP, Admin Password) + M2M
#       - Use for: Streamlit UI, user-facing applications
#    2. lakehouse-m2m-client (ID: 6dls2pick0ekciocqckh6s02ss)
#       - Supports: M2M only (client_credentials)
#       - Use for: Gateway-to-Runtime, service-to-service, test scripts
#
# ⚠️  If you see UUID usernames instead of emails:
#    1. Run: python cleanup_test_users.py
#    2. Delete the User Pool from AWS Console
#    3. Run this script again to recreate with correct settings
#
#
# ✅ Cognito setup complete!
#
# 📋 Configuration automatically saved to SSM Parameter Store

# %% [markdown]
# ## Step 2: Verify Cognito Configuration in SSM
#
# The setup_cognito.py script automatically saves all configuration to SSM Parameter Store.
# Run this cell to verify the parameters were saved correctly.

# %%
# Verify Cognito Configuration in SSM Parameter Store

print("Verifying Cognito parameters in SSM Parameter Store...\n")

# List of parameters to check
parameters_to_check = [
    '/app/lakehouse-agent/cognito-user-pool-id',
    '/app/lakehouse-agent/cognito-app-client-id',
    '/app/lakehouse-agent/cognito-domain',
    '/app/lakehouse-agent/cognito-resource-server-id',
]

# Check each parameter
all_found = True
for param_name in parameters_to_check:
    try:
        response = ssm_client.get_parameter(Name=param_name)
        value = response['Parameter']['Value']
        # Mask sensitive values
        display_value = value[:30] + '...' if len(value) > 30 else value
        print(f'✅ {param_name}')
        print(f'   Value: {display_value}')
    except ssm_client.exceptions.ParameterNotFound:
        print(f'❌ {param_name} - NOT FOUND')
        all_found = False
    except Exception as e:
        print(f'⚠️  {param_name} - ERROR: {e}')
        all_found = False

# Check secure parameters (without displaying values)
secure_params = [
    '/app/lakehouse-agent/cognito-app-client-secret',
]

for param_name in secure_params:
    try:
        response = ssm_client.get_parameter(Name=param_name, WithDecryption=False)
        print(f'✅ {param_name} (SecureString)')
        print(f'   Value: ***MASKED***')
    except ssm_client.exceptions.ParameterNotFound:
        print(f'❌ {param_name} - NOT FOUND')
        all_found = False
    except Exception as e:
        print(f'⚠️  {param_name} - ERROR: {e}')

if all_found:
    print('\n✅ All Cognito parameters verified in SSM Parameter Store!')
else:
    print('\n⚠️  Some parameters are missing. Re-run the setup_cognito.py script.')
# Out:
# Verifying Cognito parameters in SSM Parameter Store...
#
# ✅ /app/lakehouse-agent/cognito-user-pool-id
#    Value: us-east-1_3jSGececJ
# ✅ /app/lakehouse-agent/cognito-app-client-id
#    Value: comfh80kmr0a3mlrusl6cmulu
# ✅ /app/lakehouse-agent/cognito-domain
#    Value: https://lakehouse-useast13.aut...
# ✅ /app/lakehouse-agent/cognito-resource-server-id
#    Value: lakehouse-api
# ✅ /app/lakehouse-agent/cognito-app-client-secret (SecureString)
#    Value: ***MASKED***
#
# ✅ All Cognito parameters verified in SSM Parameter Store!

# %% [markdown]
# ## Summary
#
# ✅ **Cognito Deployment Complete!**
#
# **Test Users Created:**
# - user001@example.com / TempPass123!
# - user002@example.com / TempPass123!
# - adjuster001@example.com / TempPass123!
#
# **Next Steps:**
# Run **04-deploy-mcp-server.ipynb**
